# %%
import pandas as pd
import csv

from pandas.errors import ParserError


try:
    df = pd.read_csv('https://opendata.caissedesdepots.fr/api/explore/v2.1/catalog/datasets/moncompteformation_catalogueformation/exports/csv?limit=100&timezone=UTC&use_labels=false&epsg=4326', sep=";")
except ParserError:
    pass

df.head(100)
# Out:
#    date_extract                      nom_of nom_departement  \
# 0    2024-07-19                   ISTRATECH           Rhône
# 1    2024-07-19                   ISTRATECH       Côte-d'Or
# 2    2024-07-19                   ISTRATECH           Doubs
# 3    2024-07-19                   ISTRATECH           Doubs
# 4    2024-07-19                   ISTRATECH           Doubs
# ..          ...                         ...             ...
# 95   2024-07-19  JALLET JEAN MARC FORMATION             NaN
# 96   2024-07-19  JALLET JEAN MARC FORMATION             NaN
# 97   2024-07-19  JALLET JEAN MARC FORMATION             NaN
# 98   2024-07-19  JALLET JEAN MARC FORMATION             NaN
# 99   2024-07-19  JALLET JEAN MARC FORMATION            Gard
#
#                  nom_region type_referentiel  code_inventaire  code_rncp  \
# 0      Auvergne-Rhône-Alpes               RS             6203         -1
# 1   Bourgogne-Franche-Comté               RS             6204         -1
# ...

# %% [markdown]
# load test sur 100 lignes

# %%
df_test = pd.read_csv('https://opendata.caissedesdepots.fr/api/explore/v2.1/catalog/datasets/moncompteformation_catalogueformation/exports/csv?limit=100&timezone=UTC&use_labels=false&epsg=4326', sep=";")

# %%
nb = df_test.count()
print(nb)
# Out:
# date_extract                        100
# nom_of                              100
# nom_departement                      90
# nom_region                           90
# type_referentiel                    100
# code_inventaire                     100
# code_rncp                           100
# intitule_certification              100
# libelle_niveau_sortie_formation      14
# code_formacode_1                     98
# code_formacode_2                     68
# code_formacode_3                      7
# code_formacode_4                      0
# code_formacode_5                      0
# libelle_code_formacode_principal     98
# code_rome_1                          14
# code_rome_2                           5
# code_rome_3                           3
# code_rome_4                           3
# code_rome_5                           1
# libelle_nsf_1                       100
# libelle_nsf_2                         5
# libelle_nsf_3                         2
# ...

# %%
df_test.columns
# Out:
# Index(['date_extract', 'nom_of', 'nom_departement', 'nom_region',
#        'type_referentiel', 'code_inventaire', 'code_rncp',
#        'intitule_certification', 'libelle_niveau_sortie_formation',
#        'code_formacode_1', 'code_formacode_2', 'code_formacode_3',
#        'code_formacode_4', 'code_formacode_5',
#        'libelle_code_formacode_principal', 'code_rome_1', 'code_rome_2',
#        'code_rome_3', 'code_rome_4', 'code_rome_5', 'libelle_nsf_1',
#        'libelle_nsf_2', 'libelle_nsf_3', 'code_nsf_1', 'code_nsf_2',
#        'code_nsf_3', 'code_certifinfo', 'siret', 'numero_formation',
#        'intitule_formation', 'points_forts', 'nb_action', 'nb_session_active',
#        'nb_session_a_distance', 'nombre_heures_total_min',
#        'nombre_heures_total_max', 'nombre_heures_total_mean',
#        'frais_ttc_tot_min', 'frais_ttc_tot_max', 'frais_ttc_tot_mean',
#        'code_departement', 'code_region', 'nbaction_nbheures',
#        'coderegion_export'],
# ...

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 44 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   date_extract                      100 non-null    object
#  1   nom_of                            100 non-null    object
#  2   nom_departement                   90 non-null     object
#  3   nom_region                        90 non-null     object
#  4   type_referentiel                  100 non-null    object
#  5   code_inventaire                   100 non-null    int64
#  6   code_rncp                         100 non-null    int64
#  7   intitule_certification            100 non-null    object
#  8   libelle_niveau_sortie_formation   14 non-null     object
#  9   code_formacode_1                  98 non-null     float64
#  10  code_formacode_2                  68 non-null     float64
# ...

# %% [markdown]
# load integral du dataset

# %%
df_load = pd.read_csv('https://opendata.caissedesdepots.fr/api/explore/v2.1/catalog/datasets/moncompteformation_catalogueformation/exports/csv?limit=-1&timezone=UTC&use_labels=false&epsg=4326', sep=";")
# Out:
# /tmp/ipykernel_230957/3757554394.py:1: DtypeWarning: Columns (41,43) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_load = pd.read_csv('https://opendata.caissedesdepots.fr/api/explore/v2.1/catalog/datasets/moncompteformation_catalogueformation/exports/csv?limit=-1&timezone=UTC&use_labels=false&epsg=4326', sep=";")

# %%
df_load.count()
# Out:
# date_extract                        168201
# nom_of                              165027
# nom_departement                     131527
# nom_region                          131527
# type_referentiel                    168201
# code_inventaire                     168201
# code_rncp                           168201
# intitule_certification              168201
# libelle_niveau_sortie_formation      40220
# code_formacode_1                    165019
# code_formacode_2                    100546
# code_formacode_3                     21606
# code_formacode_4                      8100
# code_formacode_5                      2231
# libelle_code_formacode_principal    165019
# code_rome_1                          40976
# code_rome_2                          20868
# code_rome_3                          12357
# code_rome_4                           8237
# code_rome_5                           4682
# libelle_nsf_1                       168197
# libelle_nsf_2                        27727
# ...

# %% [markdown]
# load certif formation 1007 avant 12h35
# =>determiner la frequence des mises a jour et faire un choix pour la maj bases de données via requete api

# %%
df_load.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 212930 entries, 0 to 212929
# Data columns (total 44 columns):
#  #   Column                            Non-Null Count   Dtype
# ---  ------                            --------------   -----
#  0   date_extract                      212930 non-null  object
#  1   nom_of                            208909 non-null  object
#  2   nom_departement                   166014 non-null  object
#  3   nom_region                        166014 non-null  object
#  4   type_referentiel                  212930 non-null  object
#  5   code_inventaire                   212930 non-null  int64
#  6   code_rncp                         212930 non-null  int64
#  7   intitule_certification            212930 non-null  object
#  8   libelle_niveau_sortie_formation   51290 non-null   object
#  9   code_formacode_1                  208231 non-null  float64
#  10  code_formacode_2                  126445 non-null  float64
# ...

# %% [markdown]
# suppression des colonnes non selectionnées pour la comparaison

# %% [markdown]
# test avec date_extract

# %%
df_load_date_extract = pd.read_csv('https://opendata.caissedesdepots.fr/api/explore/v2.1/catalog/datasets/moncompteformation_catalogueformation/exports/csv?select=date_extract&limit=10&timezone=UTC&use_labels=false&epsg=4326')

# %%
df_load_date_extract.head()
# Out:
#   date_extract
# 0   2024-07-10
# 1   2024-07-10
# 2   2024-07-10
# 3   2024-07-10
# 4   2024-07-10

# %%
df_test2 = pd.read_csv('https://opendata.caissedesdepots.fr/api/explore/v2.1/catalog/datasets/moncompteformation_catalogueformation/exports/csv?select=date_extract%2C%20nom_of&limit=10&timezone=UTC&use_labels=false&epsg=4326')

# %%
df_test2.head()
# Out:
#           date_extract;nom_of
# 0       2024-07-10;A+CONSEILS
# 1       2024-07-10;A+CONSEILS
# 2       2024-07-10;A+CONSEILS
# 3  2024-07-10;A-Z Linguistics
# 4           2024-07-10;A. DOC

# %% [markdown]
# ciblage des formations similaires a simplon (codes nfs formacodes?)
# => laetitia : need of a liste of nfs1 ou autres différenciant == filtre sur dataframe

# %% [markdown]
# je choisis les colonnes gardées et je filtre sur les formations where code nfs_1 = 326

# %%
df_load_cleaned = pd.read_csv('https://opendata.caissedesdepots.fr/api/explore/v2.1/catalog/datasets/moncompteformation_catalogueformation/exports/csv?select=date_extract%2C%20nom_of%2C%20nom_departement%2C%20nom_region%2C%20type_referentiel%2C%20code_inventaire%2C%20code_rncp%2C%20intitule_certification%2C%20libelle_niveau_sortie_formation%2C%20code_formacode_1%2C%20code_formacode_2%2C%20code_formacode_3%2C%20code_formacode_4%2C%20code_formacode_5%2C%20libelle_code_formacode_principal%2C%20libelle_nsf_1%2C%20code_nsf_1%2C%20code_certifinfo%2C%20siret%2C%20numero_formation%2C%20intitule_formation%2C%20points_forts%2C%20nb_action%2C%20nb_session_active%2C%20nb_session_a_distance%2C%20nombre_heures_total_min%2C%20nombre_heures_total_max%2C%20nombre_heures_total_mean%2C%20frais_ttc_tot_min%2C%20frais_ttc_tot_max%2C%20frais_ttc_tot_mean%2C%20code_departement%2C%20code_region%2C%20nbaction_nbheures%2C%20coderegion_export&where=code_nsf_1%20%3D%20%22326%22&limit=100&timezone=UTC&use_labels=false&epsg=4326')
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[13], line 1
# ...

# %%
df_load_cleaned.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 df_load_cleaned.head()
#
# NameError: name 'df_load_cleaned' is not defined

# %% [markdown]
# ParserError avec csv passons au json

# %%
url = 'https://opendata.caissedesdepots.fr/api/explore/v2.1/catalog/datasets/moncompteformation_catalogueformation/exports/json?select=date_extract%2C%20nom_of%2C%20nom_departement%2C%20nom_region%2C%20type_referentiel%2C%20code_inventaire%2C%20code_rncp%2C%20intitule_certification%2C%20libelle_niveau_sortie_formation%2C%20code_formacode_1%2C%20code_formacode_2%2C%20code_formacode_3%2C%20code_formacode_4%2C%20code_formacode_5%2C%20libelle_code_formacode_principal%2C%20libelle_nsf_1%2C%20code_nsf_1%2C%20code_certifinfo%2C%20siret%2C%20numero_formation%2C%20intitule_formation%2C%20points_forts%2C%20nb_action%2C%20nb_session_active%2C%20nb_session_a_distance%2C%20nombre_heures_total_min%2C%20nombre_heures_total_max%2C%20nombre_heures_total_mean%2C%20frais_ttc_tot_min%2C%20frais_ttc_tot_max%2C%20frais_ttc_tot_mean%2C%20code_departement%2C%20code_region%2C%20nbaction_nbheures%2C%20coderegion_export&where=code_nsf_1%20%3D%20%22326%22&limit=100&timezone=UTC&use_labels=false&epsg=4326'
df_load_cleaned_json_url = pd.read_json(url)

# %%
df_load_cleaned_json_url.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 35 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   date_extract                      100 non-null    object
#  1   nom_of                            100 non-null    object
#  2   nom_departement                   85 non-null     object
#  3   nom_region                        85 non-null     object
#  4   type_referentiel                  100 non-null    object
#  5   code_inventaire                   100 non-null    int64
#  6   code_rncp                         100 non-null    int64
#  7   intitule_certification            100 non-null    object
#  8   libelle_niveau_sortie_formation   0 non-null      float64
#  9   code_formacode_1                  100 non-null    int64
#  10  code_formacode_2                  100 non-null    int64
# ...

# %%
url = 'https://opendata.caissedesdepots.fr/api/explore/v2.1/catalog/datasets/moncompteformation_catalogueformation/exports/json?select=date_extract%2C%20nom_of%2C%20nom_departement%2C%20nom_region%2C%20type_referentiel%2C%20code_inventaire%2C%20code_rncp%2C%20intitule_certification%2C%20libelle_niveau_sortie_formation%2C%20code_formacode_1%2C%20code_formacode_2%2C%20code_formacode_3%2C%20code_formacode_4%2C%20code_formacode_5%2C%20libelle_code_formacode_principal%2C%20libelle_nsf_1%2C%20code_nsf_1%2C%20code_certifinfo%2C%20siret%2C%20numero_formation%2C%20intitule_formation%2C%20points_forts%2C%20nb_action%2C%20nb_session_active%2C%20nb_session_a_distance%2C%20nombre_heures_total_min%2C%20nombre_heures_total_max%2C%20nombre_heures_total_mean%2C%20frais_ttc_tot_min%2C%20frais_ttc_tot_max%2C%20frais_ttc_tot_mean%2C%20code_departement%2C%20code_region%2C%20nbaction_nbheures%2C%20coderegion_export&where=code_nsf_1%20%3D%20%22326%22&limit=100&timezone=UTC&use_labels=false&epsg=4326')
df_load_cleaned_json = pd.read_json('https://opendata.caissedesdepots.fr/api/explore/v2.1/catalog/datasets/moncompteformation_catalogueformation/exports/json?select=date_extract%2C%20nom_of%2C%20nom_departement%2C%20nom_region%2C%20type_referentiel%2C%20code_inventaire%2C%20code_rncp%2C%20intitule_certification%2C%20libelle_niveau_sortie_formation%2C%20code_formacode_1%2C%20code_formacode_2%2C%20code_formacode_3%2C%20code_formacode_4%2C%20code_formacode_5%2C%20libelle_code_formacode_principal%2C%20libelle_nsf_1%2C%20code_nsf_1%2C%20code_certifinfo%2C%20siret%2C%20numero_formation%2C%20intitule_formation%2C%20points_forts%2C%20nb_action%2C%20nb_session_active%2C%20nb_session_a_distance%2C%20nombre_heures_total_min%2C%20nombre_heures_total_max%2C%20nombre_heures_total_mean%2C%20frais_ttc_tot_min%2C%20frais_ttc_tot_max%2C%20frais_ttc_tot_mean%2C%20code_departement%2C%20code_region%2C%20nbaction_nbheures%2C%20coderegion_export&where=code_nsf_1%20%3D%20%22326%22&limit=100&timezone=UTC&use_labels=false&epsg=4326')

# %%
df_load_cleaned_json.head()
# Out:
#   date_extract     nom_of   nom_departement                  nom_region  \
# 0   2024-07-11  FORMALTIC           Hérault                   Occitanie
# 1   2024-07-11  FORMALTIC  Bouches-du-Rhône  Provence-Alpes-Côte d'Azur
# 2   2024-07-11  FORMALTIC           Hérault                   Occitanie
# 3   2024-07-11  FORMALTIC           Hérault                   Occitanie
# 4   2024-07-11  FORMALTIC              None                        None
#
#   type_referentiel  code_inventaire  code_rncp intitule_certification  \
# 0               RS             6204         -1         Tosa Photoshop
# 1               RS             6204         -1         Tosa Photoshop
# 2               RS             6198         -1              Tosa Word
# 3               RS             6198         -1              Tosa Word
# 4               RS             6208         -1         Tosa WordPress
#
#    libelle_niveau_sortie_formation  code_formacode_1  ...  \
# ...

# %%
print(df_load_cleaned_json_url)
# Out:
#    date_extract                                             nom_of  \
# 0    2024-07-11                                          FORMALTIC
# 1    2024-07-11                                          FORMALTIC
# 2    2024-07-11                                          FORMALTIC
# 3    2024-07-11                                          FORMALTIC
# 4    2024-07-11                                          FORMALTIC
# ..          ...                                                ...
# 95   2024-07-11                           FORMATION DIGITAL SKILLS
# 96   2024-07-11            FORMATION ET INSERTION DEFICIENT VISUEL
# 97   2024-07-11  FORMATION INSERTION BESOINS RURAUX ET ENTREPRISES
# 98   2024-07-11                         FORMATION SAARLOR FSL EURL
# 99   2024-07-11                                 FORMATION SOLUTION
#
#      nom_departement                  nom_region type_referentiel  \
# 0            Hérault                   Occitanie               RS
# ...

# %% [markdown]
# le fichier complet

# %%
df_cf_load =

# %% [markdown]
# le fichier complet et cleaned

# %%
df_cf_cleaned = pd.read_json('https://opendata.caissedesdepots.fr/api/explore/v2.1/catalog/datasets/moncompteformation_catalogueformation/exports/json?select=date_extract%2C%20nom_of%2C%20nom_departement%2C%20nom_region%2C%20type_referentiel%2C%20code_inventaire%2C%20code_rncp%2C%20intitule_certification%2C%20libelle_niveau_sortie_formation%2C%20code_formacode_1%2C%20code_formacode_2%2C%20code_formacode_3%2C%20code_formacode_4%2C%20code_formacode_5%2C%20libelle_code_formacode_principal%2C%20libelle_nsf_1%2C%20code_nsf_1%2C%20code_certifinfo%2C%20siret%2C%20numero_formation%2C%20intitule_formation%2C%20points_forts%2C%20nb_action%2C%20nb_session_active%2C%20nb_session_a_distance%2C%20nombre_heures_total_min%2C%20nombre_heures_total_max%2C%20nombre_heures_total_mean%2C%20frais_ttc_tot_min%2C%20frais_ttc_tot_max%2C%20frais_ttc_tot_mean%2C%20code_departement%2C%20code_region%2C%20nbaction_nbheures%2C%20coderegion_export&where=code_nsf_1%20%3D%20%22326%22&limit=-1&timezone=UTC&use_labels=false&epsg=4326')

# %%
df_cf_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60703 entries, 0 to 60702
# Data columns (total 35 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   date_extract                      60703 non-null  object
#  1   nom_of                            59446 non-null  object
#  2   nom_departement                   46413 non-null  object
#  3   nom_region                        46413 non-null  object
#  4   type_referentiel                  60703 non-null  object
#  5   code_inventaire                   60703 non-null  int64
#  6   code_rncp                         60703 non-null  int64
#  7   intitule_certification            60703 non-null  object
#  8   libelle_niveau_sortie_formation   4906 non-null   object
#  9   code_formacode_1                  57571 non-null  float64
#  10  code_formacode_2                  56734 non-null  float64
# ...

# %% [markdown]
# voir le resultat et verifier la valeur de code_nfs_1 et libelle_nfs_1 : generer un file_test

# %%
import compteformation.data

# %%
df_load_cleaned_json_url.to_csv(path_or_buf='/compteformation/data/compteformation.csv', sep=',')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df_load_cleaned_json_url.to_csv(path_or_buf='/compteformation/data/compteformation.csv', sep=',')
#
# NameError: name 'df_load_cleaned_json_url' is not defined

# %% [markdown]
# logique je passe au script a l occasion de cette étape

# %% [markdown]
# je reverifie mon url pour le cleaned one 1107

# %%
test_def = pd.read_json('https://opendata.caissedesdepots.fr/api/explore/v2.1/catalog/datasets/moncompteformation_catalogueformation/exports/json?select=date_extract%2C%20nom_of%2C%20nom_departement%2C%20nom_region%2C%20type_referentiel%2C%20code_inventaire%2C%20code_rncp%2C%20intitule_certification%2C%20libelle_niveau_sortie_formation%2C%20code_formacode_1%2C%20code_formacode_2%2C%20code_formacode_3%2C%20code_formacode_4%2C%20code_formacode_5%2C%20libelle_code_formacode_principal%2C%20libelle_nsf_1%2C%20code_nsf_1%2C%20code_certifinfo%2C%20siret%2C%20numero_formation%2C%20intitule_formation%2C%20points_forts%2C%20nb_action%2C%20nb_session_active%2C%20nb_session_a_distance%2C%20nombre_heures_total_min%2C%20nombre_heures_total_max%2C%20nombre_heures_total_mean%2C%20frais_ttc_tot_min%2C%20frais_ttc_tot_max%2C%20frais_ttc_tot_mean%2C%20code_departement%2C%20code_region%2C%20nbaction_nbheures%2C%20coderegion_export&where=code_nsf_1%20%3D%20%22326%22&limit=-1&timezone=UTC&use_labels=false&epsg=4326')

# %%
test_def.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60703 entries, 0 to 60702
# Data columns (total 35 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   date_extract                      60703 non-null  object
#  1   nom_of                            59446 non-null  object
#  2   nom_departement                   46413 non-null  object
#  3   nom_region                        46413 non-null  object
#  4   type_referentiel                  60703 non-null  object
#  5   code_inventaire                   60703 non-null  int64
#  6   code_rncp                         60703 non-null  int64
#  7   intitule_certification            60703 non-null  object
#  8   libelle_niveau_sortie_formation   4906 non-null   object
#  9   code_formacode_1                  57571 non-null  float64
#  10  code_formacode_2                  56734 non-null  float64
# ...

# %% [markdown]
# cf script: pb avec les points forts je les vire le reste c est clean

# %% [markdown]
# confronter avec le code de scrapping

# %%
test_def_1507 = pd.read_json('https://opendata.caissedesdepots.fr/api/explore/v2.1/catalog/datasets/moncompteformation_catalogueformation/exports/json?select=date_extract%2C%20nom_of%2C%20nom_departement%2C%20nom_region%2C%20type_referentiel%2C%20code_inventaire%2C%20code_rncp%2C%20intitule_certification%2C%20libelle_niveau_sortie_formation%2C%20code_formacode_1%2C%20code_formacode_2%2C%20code_formacode_3%2C%20code_formacode_4%2C%20code_formacode_5%2C%20libelle_code_formacode_principal%2C%20libelle_nsf_1%2C%20code_nsf_1%2C%20code_certifinfo%2C%20siret%2C%20numero_formation%2C%20intitule_formation%2C%20points_forts%2C%20nb_action%2C%20nb_session_active%2C%20nb_session_a_distance%2C%20nombre_heures_total_min%2C%20nombre_heures_total_max%2C%20nombre_heures_total_mean%2C%20frais_ttc_tot_min%2C%20frais_ttc_tot_max%2C%20frais_ttc_tot_mean%2C%20code_departement%2C%20code_region%2C%20nbaction_nbheures%2C%20coderegion_export&where=code_nsf_1%20%3D%20%22326%22&limit=-1&timezone=UTC&use_labels=false&epsg=4326')

# %%
test_def_1507.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61029 entries, 0 to 61028
# Data columns (total 35 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   date_extract                      61029 non-null  object
#  1   nom_of                            59772 non-null  object
#  2   nom_departement                   46726 non-null  object
#  3   nom_region                        46726 non-null  object
#  4   type_referentiel                  61029 non-null  object
#  5   code_inventaire                   61029 non-null  int64
#  6   code_rncp                         61029 non-null  int64
#  7   intitule_certification            61029 non-null  object
#  8   libelle_niveau_sortie_formation   4906 non-null   object
#  9   code_formacode_1                  57900 non-null  float64
#  10  code_formacode_2                  57065 non-null  float64
# ...

# %% [markdown]
# CLEAN DE COMPTE FORMATION: LE CODE CERTIF
# je recupere le df_cf_cleaned
# clean sur code inventaire code rncp
# j insert la colonne id_certif au bon endroit
# je lui affecte une valeur en aprcourant les lignes du csv
# la variable recoit, a chaque pas, toujours la valeur d une des deux autres si elle est differente de -1
# construire une nelle colonne a partir d elle

# %%
url = 'https://opendata.caissedesdepots.fr/api/explore/v2.1/catalog/datasets/moncompteformation_catalogueformation/exports/json?select=date_extract%2C%20nom_of%2C%20nom_departement%2C%20nom_region%2C%20type_referentiel%2C%20code_inventaire%2C%20code_rncp%2C%20intitule_certification%2C%20libelle_niveau_sortie_formation%2C%20code_formacode_1%2C%20code_formacode_2%2C%20code_formacode_3%2C%20code_formacode_4%2C%20code_formacode_5%2C%20libelle_code_formacode_principal%2C%20libelle_nsf_1%2C%20code_nsf_1%2C%20code_certifinfo%2C%20siret%2C%20numero_formation%2C%20intitule_formation%2C%20points_forts%2C%20nb_action%2C%20nb_session_active%2C%20nb_session_a_distance%2C%20nombre_heures_total_min%2C%20nombre_heures_total_max%2C%20nombre_heures_total_mean%2C%20frais_ttc_tot_min%2C%20frais_ttc_tot_max%2C%20frais_ttc_tot_mean%2C%20code_departement%2C%20code_region%2C%20nbaction_nbheures%2C%20coderegion_export&where=code_nsf_1%20%3D%20%22326%22&limit=100&timezone=UTC&use_labels=false&epsg=4326'

# %%
df_cf_tst =pd.read_json(url)

# %%
df_cf_tst.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 35 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   date_extract                      100 non-null    object
#  1   nom_of                            100 non-null    object
#  2   nom_departement                   66 non-null     object
#  3   nom_region                        66 non-null     object
#  4   type_referentiel                  100 non-null    object
#  5   code_inventaire                   100 non-null    int64
#  6   code_rncp                         100 non-null    int64
#  7   intitule_certification            100 non-null    object
#  8   libelle_niveau_sortie_formation   9 non-null      object
#  9   code_formacode_1                  100 non-null    int64
#  10  code_formacode_2                  99 non-null     float64
# ...

# %%
df_cf_tst.head()
# Out:
#   date_extract       nom_of   nom_departement        nom_region  \
# 0   2024-07-19    ENI ECOLE              None              None
# 1   2024-07-19    ENI ECOLE  Loire-Atlantique  Pays de la Loire
# 2   2024-07-19  ENI SERVICE  Loire-Atlantique  Pays de la Loire
# 3   2024-07-19  ENI SERVICE   Ille-et-Vilaine          Bretagne
# 4   2024-07-19  ENI SERVICE              None              None
#
#   type_referentiel  code_inventaire  code_rncp  \
# 0             RNCP               -1      37674
# 1             RNCP               -1      37682
# 2               RS             5375         -1
# 3               RS             5375         -1
# 4               RS             5375         -1
#
#                            intitule_certification  \
# 0                TP Développeur web et web mobile
# 1     TP Technicien supérieur systèmes et réseaux
# 2  Administrer les services Cloud Microsoft Azure
# 3  Administrer les services Cloud Microsoft Azure
# ...

# %% [markdown]
# creation de id_certif a la place des 2 colonnes code_inventaire & code_rncp

# %%
for i in range(len(df_cf_tst['code_inventaire'])):
               if df_cf_tst.loc[i, 'type_referentiel'] == 'RS':
                                              df_cf_tst.loc[i, 'code_rncp'] = df_cf_tst.loc[i, 'code_inventaire']

# %%
df_cf_tst.head()
# Out:
#   date_extract       nom_of   nom_departement        nom_region  \
# 0   2024-07-19    ENI ECOLE              None              None
# 1   2024-07-19    ENI ECOLE  Loire-Atlantique  Pays de la Loire
# 2   2024-07-19  ENI SERVICE  Loire-Atlantique  Pays de la Loire
# 3   2024-07-19  ENI SERVICE   Ille-et-Vilaine          Bretagne
# 4   2024-07-19  ENI SERVICE              None              None
#
#   type_referentiel  code_inventaire  code_rncp  \
# 0             RNCP               -1      37674
# 1             RNCP               -1      37682
# 2               RS             5375       5375
# 3               RS             5375       5375
# 4               RS             5375       5375
#
#                            intitule_certification  \
# 0                TP Développeur web et web mobile
# 1     TP Technicien supérieur systèmes et réseaux
# 2  Administrer les services Cloud Microsoft Azure
# 3  Administrer les services Cloud Microsoft Azure
# ...

# %%
df_cf_tst = df_cf_tst.rename(columns={'code_rncp': 'id_certif'})

# %%
#df_cf_tst.drop('code_inventaire', axis=1)
del df_cf_tst['code_inventaire']

# %% [markdown]
# indexation id_compte_formation

# %%
df_cf_tst.insert(0, 'id_compte_formation', range(0, len(df_cf_tst)))
df_cf_tst
# Out:
#     id_compte_formation date_extract                     nom_of  \
# 0                     0   2024-07-19                  ENI ECOLE
# 1                     1   2024-07-19                  ENI ECOLE
# 2                     2   2024-07-19                ENI SERVICE
# 3                     3   2024-07-19                ENI SERVICE
# 4                     4   2024-07-19                ENI SERVICE
# ..                  ...          ...                        ...
# 95                   95   2024-07-19  ESPACE FORMATION GRENOBLE
# 96                   96   2024-07-19              ESPACE PROJET
# 97                   97   2024-07-19              ESPACE PROJET
# 98                   98   2024-07-19              ESPACE PROJET
# 99                   99   2024-07-19              ESPACE PROJET
#
#      nom_departement        nom_region type_referentiel  id_certif  \
# 0               None              None             RNCP      37674
# ...

# %%
df_cf_tst.head()
# Out:
#    id_compte_formation date_extract       nom_of   nom_departement  \
# 0                    0   2024-07-19    ENI ECOLE              None
# 1                    1   2024-07-19    ENI ECOLE  Loire-Atlantique
# 2                    2   2024-07-19  ENI SERVICE  Loire-Atlantique
# 3                    3   2024-07-19  ENI SERVICE   Ille-et-Vilaine
# 4                    4   2024-07-19  ENI SERVICE              None
#
#          nom_region type_referentiel  id_certif  \
# 0              None             RNCP      37674
# 1  Pays de la Loire             RNCP      37682
# 2  Pays de la Loire               RS       5375
# 3          Bretagne               RS       5375
# 4              None               RS       5375
#
#                            intitule_certification  \
# 0                TP Développeur web et web mobile
# 1     TP Technicien supérieur systèmes et réseaux
# 2  Administrer les services Cloud Microsoft Azure
# 3  Administrer les services Cloud Microsoft Azure
# ...

# %%
df_cf_tst.set_index(keys=['id_compte_formation'], inplace=True)

# %%
df_cf_tst.head()
# Out:
#                     date_extract       nom_of   nom_departement  \
# id_compte_formation
# 0                     2024-07-19    ENI ECOLE              None
# 1                     2024-07-19    ENI ECOLE  Loire-Atlantique
# 2                     2024-07-19  ENI SERVICE  Loire-Atlantique
# 3                     2024-07-19  ENI SERVICE   Ille-et-Vilaine
# 4                     2024-07-19  ENI SERVICE              None
#
#                            nom_region type_referentiel  id_certif  \
# id_compte_formation
# 0                                None             RNCP      37674
# 1                    Pays de la Loire             RNCP      37682
# 2                    Pays de la Loire               RS       5375
# 3                            Bretagne               RS       5375
# 4                                None               RS       5375
#
#                                              intitule_certification  \
# id_compte_formation
# ...

# %% [markdown]
# passage d index a colonne id_compte_formation

# %%
df_cf_tst.reset_index(drop=True, inplace=True, names=['id_compte_formation'])

# %%
df_cf_tst.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 34 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   date_extract                      100 non-null    object
#  1   nom_of                            100 non-null    object
#  2   nom_departement                   66 non-null     object
#  3   nom_region                        66 non-null     object
#  4   type_referentiel                  100 non-null    object
#  5   id_certif                         100 non-null    int64
#  6   intitule_certification            100 non-null    object
#  7   libelle_niveau_sortie_formation   9 non-null      object
#  8   code_formacode_1                  100 non-null    int64
#  9   code_formacode_2                  99 non-null     float64
#  10  code_formacode_3                  47 non-null     float64
# ...

# %%
df_cf_tst.head()
# Out:
#   date_extract       nom_of   nom_departement        nom_region  \
# 0   2024-07-19    ENI ECOLE              None              None
# 1   2024-07-19    ENI ECOLE  Loire-Atlantique  Pays de la Loire
# 2   2024-07-19  ENI SERVICE  Loire-Atlantique  Pays de la Loire
# 3   2024-07-19  ENI SERVICE   Ille-et-Vilaine          Bretagne
# 4   2024-07-19  ENI SERVICE              None              None
#
#   type_referentiel  id_certif                          intitule_certification  \
# 0             RNCP      37674                TP Développeur web et web mobile
# 1             RNCP      37682     TP Technicien supérieur systèmes et réseaux
# 2               RS       5375  Administrer les services Cloud Microsoft Azure
# 3               RS       5375  Administrer les services Cloud Microsoft Azure
# 4               RS       5375  Administrer les services Cloud Microsoft Azure
#
#        libelle_niveau_sortie_formation  code_formacode_1  code_formacode_2  \
# ...

# %% [markdown]
# union de type referentiel et id_certif

# %%
type(df_cf_tst['id_certif'][0])
df_cf_tst['id_certif'] = df_cf_tst['id_certif'].astype(str)

# %%
print(df_cf_tst['id_certif'].dtype)
# Out:
# object

# %%
df_cf_tst['id_certif'] = df_cf_tst['type_referentiel'] + df_cf_tst['id_certif']

# %%
df_cf_tst.head()
# Out:
#                     date_extract       nom_of   nom_departement  \
# id_compte_formation
# 0                     2024-07-19    ENI ECOLE              None
# 1                     2024-07-19    ENI ECOLE  Loire-Atlantique
# 2                     2024-07-19  ENI SERVICE  Loire-Atlantique
# 3                     2024-07-19  ENI SERVICE   Ille-et-Vilaine
# 4                     2024-07-19  ENI SERVICE              None
#
#                            nom_region type_referentiel  id_certif  \
# id_compte_formation
# 0                                None             RNCP  RNCP37674
# 1                    Pays de la Loire             RNCP  RNCP37682
# 2                    Pays de la Loire               RS     RS5375
# 3                            Bretagne               RS     RS5375
# 4                                None               RS     RS5375
#
#                                              intitule_certification  \
# id_compte_formation
# ...

# %%
del df_cf_tst['type_referentiel']

# %%
df_cf_tst.head()
# Out:
#                     date_extract       nom_of   nom_departement  \
# id_compte_formation
# 0                     2024-07-19    ENI ECOLE              None
# 1                     2024-07-19    ENI ECOLE  Loire-Atlantique
# 2                     2024-07-19  ENI SERVICE  Loire-Atlantique
# 3                     2024-07-19  ENI SERVICE   Ille-et-Vilaine
# 4                     2024-07-19  ENI SERVICE              None
#
#                            nom_region  id_certif  \
# id_compte_formation
# 0                                None  RNCP37674
# 1                    Pays de la Loire  RNCP37682
# 2                    Pays de la Loire     RS5375
# 3                            Bretagne     RS5375
# 4                                None     RS5375
#
#                                              intitule_certification  \
# id_compte_formation
# 0                                  TP Développeur web et web mobile
# 1                       TP Technicien supérieur systèmes et réseaux
# ...
